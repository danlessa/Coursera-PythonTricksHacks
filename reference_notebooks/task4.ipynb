# %% [markdown]
# # Type hinting
#
# Reference notebook for the fourth task of the *Python Tricks and Hacks for Productivity* course on Coursera.
#
# **Instructor**: *Danilo Lessa Bernardineli (danilo.bernardineli@usp.br)*

# %%
def function(param_1, param_2, param_3):
    var_1 = param_1 - param_2
    var_2 = param_3 & param_2
    var_3 = var_2 | var_1
    return var_3

# %%
a = {1, 2, 3}
b = {3, 4, 5}
c = {5, 6, 7}
r = function(a, b, c)
r
# Out:
# {1, 2, 5}

# %%
function(1, 2, 3)
# Out:
# -1

# %%
function(1.5, 2.5, 3.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-c384ff4f2543> in <module>
# ----> 1 function(1.5, 2.5, 3.5)
#
# <ipython-input-1-24daf6a8719b> in function(param_1, param_2, param_3)
#       1 def function(param_1, param_2, param_3):
#       2     var_1 = param_1 - param_2
# ----> 3     var_2 = param_3 & param_2
#       4     var_3 = var_2 | var_1
#       5     return var_3
#
# TypeError: unsupported operand type(s) for &: 'float' and 'float'

# %%
def function(param_1: set, 
             param_2: set, 
             param_3: set) -> set:
    var_1 = param_1 - param_2
    var_2 = param_3 & param_2
    var_3 = var_2 | var_1
    return var_3


def function(param_1: int, 
             param_2: int, 
             param_3: int) -> int:
    var_1 = param_1 - param_2
    var_2 = param_3 & param_2
    var_3 = var_2 | var_1
    return var_3

# %%
def function(param_1: set, 
             param_2: set, 
             param_3: set) -> set:
    var_1 = param_1 - param_2
    var_2 = param_3 & param_2
    var_3 = var_2 | var_1
    return var_3

a: set = {1, 2, 3}
b: set = {3, 4, 5}
c: set = {5, 6, 7}
r: set = function(a, b, c)
r
# Out:
# {1, 2, 5}

# %%
a: object = None
b: dict = {'a': 5}
c: list = [1]

# %%
def function(a: float,
             b: dict={},
             c: list=[]) -> bool:
    pass
